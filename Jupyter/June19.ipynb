# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\ANSHU\Desktop\AIMLTraining\Assignment\Dataset\Medicaldataset.csv")

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   str
# dtypes: float64(3), int64(5), str(1)
# memory usage: 92.9 KB

# %%
data[data["Gender"]==0]
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 5      58       0          61                      112
# 6      32       0          40                      179
# 8      44       0          60                      154
# 10     44       0          60                      166
# 11     63       0          60                      150
# ...   ...     ...         ...                      ...
# 1303   55       0          80                      117
# 1304   56       0          68                      123
# 1306   60       0          78                      109
# 1310   70       0          80                      135
# 1313   86       0          40                      179
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 5                           58         87.0   1.83     0.004  negative
# 6                           68        102.0   0.71     0.003  negative
# 8                           81        135.0   2.35     0.004  negative
# ...

# %%
data.groupby(["Gender","Result"])

# %%
data["Result"]
# Out:
# 0       negative
# 1       positive
# 2       negative
# 3       positive
# 4       negative
#           ...
# 1314    negative
# 1315    positive
# 1316    positive
# 1317    positive
# 1318    positive
# Name: Result, Length: 1319, dtype: str

# %%
data[data["Result"]=="positive"]
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 1      21       1          94                       98
# 3      64       1          70                      120
# 7      63       1          60                      214
# 12     64       1          60                      199
# 15     61       1          81                      118
# ...   ...     ...         ...                      ...
# 1311   85       1         112                      115
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 1                           46        296.0    6.75     1.060  positive
# 3                           55        270.0   13.87     0.122  positive
# 7                           82         87.0  300.00     2.370  positive
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
list=data["Age"][data["Result"]=="positive"]

# %%
print(list)
# Out:
# 1       21
# 3       64
# 7       63
# 12      64
# 15      61
#         ..
# 1311    85
# 1315    66
# 1316    45
# 1317    54
# 1318    51
# Name: Age, Length: 810, dtype: int64

# %%
data.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %%
plt.hist(data["Result"],bins=3)
# Out:
# (array([509.,   0., 810.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.plot(data["Age"],data["Gender"])
plt.show()

# %%
arr1=np.array(data.iloc[0:7])

# %%
arr1
# Out:
# array([[64, 1, 66, 160, 83, 160.0, 1.8, 0.012, 'negative'],
#        [21, 1, 94, 98, 46, 296.0, 6.75, 1.06, 'positive'],
#        [55, 1, 64, 160, 77, 270.0, 1.99, 0.003, 'negative'],
#        [64, 1, 70, 120, 55, 270.0, 13.87, 0.122, 'positive'],
#        [55, 1, 64, 112, 65, 300.0, 1.08, 0.003, 'negative'],
#        [58, 0, 61, 112, 58, 87.0, 1.83, 0.004, 'negative'],
#        [32, 0, 40, 179, 68, 102.0, 0.71, 0.003, 'negative']], dtype=object)

# %%
plt.plot(data["Systolic blood pressure"],data["Diastolic blood pressure"])

# %%
total=data["Gender"].count()

# %%
male=data[data["Gender"]==1]

# %%
female=data[data["Gender"]==0]

# %%
plt.pie(data["Gender"].value_counts(),labels=["Male","female"])
plt.show()

# %%
plt.pie(data["Result"].value_counts(),labels=["Positive","Negative"])
print(data[data["Result"]=="positive"].value_counts)
print(data[data["Result"]=="negative"].value_counts)
# Out:
# <bound method DataFrame.value_counts of       Age  Gender  Heart rate  Systolic blood pressure  \
# 1      21       1          94                       98
# 3      64       1          70                      120
# 7      63       1          60                      214
# 12     64       1          60                      199
# 15     61       1          81                      118
# ...   ...     ...         ...                      ...
# 1311   85       1         112                      115
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 1                           46        296.0    6.75     1.060  positive
# 3                           55        270.0   13.87     0.122  positive
# ...

# %%
sns.barplot(data["Result"])
# Out:
# <Axes: ylabel='Result'>

# %%
arr1=np.array(data.sort_values)

# %%
plt.plot(data["Age"],data["Heart rate"])

# %%
data.sort_values(by="Age",inplace=True)

# %%
data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 899    14       0          89                      111
# 500    19       0          70                      117
# 1269   19       1          68                      116
# 97     19       0          62                      114
# 109    20       1          60                      156
# ...   ...     ...         ...                      ...
# 1181   90       0         125                      121
# 297    91       1          80                       65
# 896   100       1          60                      209
# 1039  103       0          86                      146
# 1126  103       0          56                      171
#
#       Diastolic blood pressure  Blood sugar    CK-MB  Troponin    Result
# 899                         57        133.0    2.620     0.012  negative
# 500                         76         91.0   36.240     0.025  positive
# 1269                        74         99.0    0.606     0.003  negative
# ...
