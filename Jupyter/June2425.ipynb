# %% [markdown]
# Working on "Indian Engineering College Placement Dataset"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\ANSHU\Desktop\AIMLTraining\Assignment\Dataset\indian_engineering_student_placement.csv")

# %%
data
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 0              1    Male    ECE   8.74              74.0                75.0
# 1              2  Female    ECE   7.80              75.3                69.7
# 2              3  Female     IT   6.95              62.8                68.3
# 3              4    Male    ECE   7.46              57.9                51.4
# 4              5    Male     IT   6.86              61.3                73.5
# ...          ...     ...    ...    ...               ...                 ...
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student_ID                   5000 non-null   int64
#  1   gender                       5000 non-null   str
#  2   branch                       5000 non-null   str
#  3   cgpa                         5000 non-null   float64
#  4   tenth_percentage             5000 non-null   float64
#  5   twelfth_percentage           5000 non-null   float64
#  6   backlogs                     5000 non-null   int64
#  7   study_hours_per_day          5000 non-null   float64
#  8   attendance_percentage        5000 non-null   float64
#  9   projects_completed           5000 non-null   int64
#  10  internships_completed        5000 non-null   int64
#  11  coding_skill_rating          5000 non-null   int64
#  12  communication_skill_rating   5000 non-null   int64
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#    Student_ID  gender branch  cgpa  tenth_percentage  twelfth_percentage  \
# 0           1    Male    ECE  8.74              74.0                75.0
# 1           2  Female    ECE  7.80              75.3                69.7
# 2           3  Female     IT  6.95              62.8                68.3
# 3           4    Male    ECE  7.46              57.9                51.4
# 4           5    Male     IT  6.86              61.3                73.5
#
#    backlogs  study_hours_per_day  attendance_percentage  projects_completed  \
# 0         0                  3.8                   71.1                   7
# 1         0                  6.3                   69.5                   5
# 2         0                  1.5                   62.5                   8
# 3         1                  4.7                   64.6                   6
# 4         2                  5.2                   75.9                   3
#
# ...

# %%
data.tail()
# Out:
#       Student_ID  gender branch   cgpa  tenth_percentage  twelfth_percentage  \
# 4995        4996  Female     IT  10.00              90.4                98.3
# 4996        4997    Male     IT   7.76              74.3                72.6
# 4997        4998    Male     IT   7.79              64.0                71.2
# 4998        4999  Female    ECE   8.76              74.3                74.0
# 4999        5000    Male    CSE   9.45              85.6                80.0
#
#       backlogs  study_hours_per_day  attendance_percentage  \
# 4995         0                  3.7                   75.3
# 4996         2                  6.3                   72.3
# 4997         2                  2.0                   63.8
# 4998         0                  5.1                   72.0
# 4999         0                  2.8                   63.4
#
#       projects_completed  ...  certifications_count  sleep_hours  \
# 4995                   6  ...                     2          7.3
# ...

# %%
data.isnull().sum()
# Out:
# Student_ID                        0
# gender                            0
# branch                            0
# cgpa                              0
# tenth_percentage                  0
# twelfth_percentage                0
# backlogs                          0
# study_hours_per_day               0
# attendance_percentage             0
# projects_completed                0
# internships_completed             0
# coding_skill_rating               0
# communication_skill_rating        0
# aptitude_skill_rating             0
# hackathons_participated           0
# certifications_count              0
# sleep_hours                       0
# stress_level                      0
# part_time_job                     0
# family_income_level               0
# city_tier                         0
# internet_access                   0
# extracurricular_involvement    1006
# placement_status                  0
# salary_lpa                        0
# dtype: int64

# %%
data['extracurricular_involvement'].value_counts()
# Out:
# extracurricular_involvement
# Medium    1501
# Low       1485
# High      1008
# Name: count, dtype: int64

# %%
data['extracurricular_involvement']=data['extracurricular_involvement'].fillna('Low')

# %%
data['extracurricular_involvement'].value_counts()
# Out:
# extracurricular_involvement
# Low       2491
# Medium    1501
# High      1008
# Name: count, dtype: int64

# %% [markdown]
# openpyexcel, joblib

# %% [markdown]
# Univariate

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student_ID                   5000 non-null   int64
#  1   gender                       5000 non-null   str
#  2   branch                       5000 non-null   str
#  3   cgpa                         5000 non-null   float64
#  4   tenth_percentage             5000 non-null   float64
#  5   twelfth_percentage           5000 non-null   float64
#  6   backlogs                     5000 non-null   int64
#  7   study_hours_per_day          5000 non-null   float64
#  8   attendance_percentage        5000 non-null   float64
#  9   projects_completed           5000 non-null   int64
#  10  internships_completed        5000 non-null   int64
#  11  coding_skill_rating          5000 non-null   int64
#  12  communication_skill_rating   5000 non-null   int64
# ...

# %% [markdown]
# saving cleaned data

# %%
import os
data.to_csv('indian_engineering_student_placement_cleaned.csv')

# %%
sns.histplot(data=data,x='cgpa',hue='gender',kde=True,color="purple")
# Out:
# <Axes: xlabel='cgpa', ylabel='Count'>

# %%
sns.countplot(data=data,x="branch",hue="gender")
# Out:
# <Axes: xlabel='branch', ylabel='count'>

# %%
plt.pie(x=data['gender'].value_counts(),labels=['Male','Female'])

# %%
plt.pie(x=data['placement_status'].value_counts(),labels=['Placed','Unplaced'])
plt.show()

# %% [markdown]
# Bivariate Visualization

# %%
sns.boxplot(data=data,x='branch',y='cgpa')
plt.title("CGPA distribution across branches")
# Out:
# Text(0.5, 1.0, 'CGPA distribution across branches')

# %%
sns.scatterplot(data=data,x='study_hours_per_day',y='cgpa',hue='stress_level',palette='viridis')
# Out:
# <Axes: xlabel='study_hours_per_day', ylabel='cgpa'>

# %%
sns.heatmap(data.corr(numeric_only=True),annot=False,cmap='coolwarm')
# Out:
# <Axes: >
